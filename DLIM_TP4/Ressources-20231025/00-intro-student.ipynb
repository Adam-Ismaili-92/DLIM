# %% [markdown]
# # DLIM 2023 Lab 04: Detection
#
# This work is heavily based on the [excellent chapters](https://d2l.ai/chapter_computer-vision/index.html) on detection from [Dive into Deep Learning](https://d2l.ai/).
#
# ![](https://d2l.ai/_images/front-cup.jpg)
#
# The original work is made available under the Creative Commons Attribution-ShareAlike 4.0 International Public License, with code samples available under the MIT license.
#
# As such, this derivative work is also licensed under the [Creative Commons BY-SA 4.0 International License](https://creativecommons.org/licenses/by-sa/4.0/).

# %% [markdown]
# Modifications include some code to rewrite, extra questions, some minor clarifications, etc.

# %% [markdown]
# ## Requirements
#
# You may need to install the following Python packages:

# %%
# %pip install torch torchvision d2l
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torch in /home/adam/.local/lib/python3.10/site-packages (2.0.1)
# Requirement already satisfied: torchvision in /home/adam/.local/lib/python3.10/site-packages (0.15.2)
# Requirement already satisfied: d2l in /home/adam/.local/lib/python3.10/site-packages (1.0.3)
# Requirement already satisfied: triton==2.0.0 in /home/adam/.local/lib/python3.10/site-packages (from torch) (2.0.0)
# Requirement already satisfied: jinja2 in /home/adam/.local/lib/python3.10/site-packages (from torch) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/adam/.local/lib/python3.10/site-packages (from torch) (11.7.99)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /home/adam/.local/lib/python3.10/site-packages (from torch) (2.14.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /home/adam/.local/lib/python3.10/site-packages (from torch) (11.7.101)
# Requirement already satisfied: sympy in /home/adam/.local/lib/python3.10/site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /home/adam/.local/lib/python3.10/site-packages (from torch) (2.8.5)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /home/adam/.local/lib/python3.10/site-packages (from torch) (10.2.10.91)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/adam/.local/lib/python3.10/site-packages (from torch) (11.7.99)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /home/adam/.local/lib/python3.10/site-packages (from torch) (11.7.4.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /home/adam/.local/lib/python3.10/site-packages (from torch) (11.4.0.1)
# Requirement already satisfied: typing-extensions in /home/adam/.local/lib/python3.10/site-packages (from torch) (4.7.1)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /home/adam/.local/lib/python3.10/site-packages (from torch) (11.7.91)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/adam/.local/lib/python3.10/site-packages (from torch) (10.9.0.58)
# Requirement already satisfied: filelock in /home/adam/.local/lib/python3.10/site-packages (from torch) (3.12.4)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/adam/.local/lib/python3.10/site-packages (from torch) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/adam/.local/lib/python3.10/site-packages (from torch) (11.10.3.66)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (59.6.0)
# Requirement already satisfied: wheel in /usr/lib/python3/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (0.37.1)
# Requirement already satisfied: cmake in /home/adam/.local/lib/python3.10/site-packages (from triton==2.0.0->torch) (3.27.5)
# Requirement already satisfied: lit in /home/adam/.local/lib/python3.10/site-packages (from triton==2.0.0->torch) (17.0.1)
# Requirement already satisfied: numpy in /home/adam/.local/lib/python3.10/site-packages (from torchvision) (1.23.5)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/adam/.local/lib/python3.10/site-packages (from torchvision) (10.0.1)
# Requirement already satisfied: requests in /home/adam/.local/lib/python3.10/site-packages (from torchvision) (2.31.0)
# Requirement already satisfied: matplotlib==3.7.2 in /home/adam/.local/lib/python3.10/site-packages (from d2l) (3.7.2)
# Requirement already satisfied: matplotlib-inline==0.1.6 in /home/adam/.local/lib/python3.10/site-packages (from d2l) (0.1.6)
# Requirement already satisfied: jupyter==1.0.0 in /home/adam/.local/lib/python3.10/site-packages (from d2l) (1.0.0)
# Requirement already satisfied: pandas==2.0.3 in /home/adam/.local/lib/python3.10/site-packages (from d2l) (2.0.3)
# Requirement already satisfied: scipy==1.10.1 in /home/adam/.local/lib/python3.10/site-packages (from d2l) (1.10.1)
# Requirement already satisfied: ipywidgets in /home/adam/.local/lib/python3.10/site-packages (from jupyter==1.0.0->d2l) (8.1.0)
# Requirement already satisfied: ipykernel in /home/adam/.local/lib/python3.10/site-packages (from jupyter==1.0.0->d2l) (6.25.2)
# Requirement already satisfied: notebook in /home/adam/.local/lib/python3.10/site-packages (from jupyter==1.0.0->d2l) (7.0.3)
# Requirement already satisfied: qtconsole in /home/adam/.local/lib/python3.10/site-packages (from jupyter==1.0.0->d2l) (5.4.4)
# Requirement already satisfied: nbconvert in /home/adam/.local/lib/python3.10/site-packages (from jupyter==1.0.0->d2l) (7.8.0)
# Requirement already satisfied: jupyter-console in /home/adam/.local/lib/python3.10/site-packages (from jupyter==1.0.0->d2l) (6.6.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/adam/.local/lib/python3.10/site-packages (from matplotlib==3.7.2->d2l) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /home/adam/.local/lib/python3.10/site-packages (from matplotlib==3.7.2->d2l) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/adam/.local/lib/python3.10/site-packages (from matplotlib==3.7.2->d2l) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/adam/.local/lib/python3.10/site-packages (from matplotlib==3.7.2->d2l) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib==3.7.2->d2l) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /home/adam/.local/lib/python3.10/site-packages (from matplotlib==3.7.2->d2l) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /home/adam/.local/lib/python3.10/site-packages (from matplotlib==3.7.2->d2l) (4.42.1)
# Requirement already satisfied: traitlets in /home/adam/.local/lib/python3.10/site-packages (from matplotlib-inline==0.1.6->d2l) (5.9.0)
# Requirement already satisfied: pytz>=2020.1 in /home/adam/.local/lib/python3.10/site-packages (from pandas==2.0.3->d2l) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/adam/.local/lib/python3.10/site-packages (from pandas==2.0.3->d2l) (2023.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/adam/.local/lib/python3.10/site-packages (from requests->torchvision) (2023.7.22)
# Requirement already satisfied: idna<4,>=2.5 in /home/adam/.local/lib/python3.10/site-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/adam/.local/lib/python3.10/site-packages (from requests->torchvision) (2.0.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/adam/.local/lib/python3.10/site-packages (from requests->torchvision) (3.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/adam/.local/lib/python3.10/site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /home/adam/.local/lib/python3.10/site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib==3.7.2->d2l) (1.16.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/adam/.local/lib/python3.10/site-packages (from ipykernel->jupyter==1.0.0->d2l) (5.3.1)
# Requirement already satisfied: pyzmq>=20 in /home/adam/.local/lib/python3.10/site-packages (from ipykernel->jupyter==1.0.0->d2l) (25.1.1)
# Requirement already satisfied: psutil in /home/adam/.local/lib/python3.10/site-packages (from ipykernel->jupyter==1.0.0->d2l) (5.9.5)
# Requirement already satisfied: tornado>=6.1 in /home/adam/.local/lib/python3.10/site-packages (from ipykernel->jupyter==1.0.0->d2l) (6.3.3)
# Requirement already satisfied: ipython>=7.23.1 in /home/adam/.local/lib/python3.10/site-packages (from ipykernel->jupyter==1.0.0->d2l) (7.34.0)
# Requirement already satisfied: debugpy>=1.6.5 in /home/adam/.local/lib/python3.10/site-packages (from ipykernel->jupyter==1.0.0->d2l) (1.7.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/adam/.local/lib/python3.10/site-packages (from ipykernel->jupyter==1.0.0->d2l) (8.3.1)
# Requirement already satisfied: nest-asyncio in /home/adam/.local/lib/python3.10/site-packages (from ipykernel->jupyter==1.0.0->d2l) (1.5.7)
# Requirement already satisfied: comm>=0.1.1 in /home/adam/.local/lib/python3.10/site-packages (from ipykernel->jupyter==1.0.0->d2l) (0.1.4)
# Requirement already satisfied: jupyterlab-widgets~=3.0.7 in /home/adam/.local/lib/python3.10/site-packages (from ipywidgets->jupyter==1.0.0->d2l) (3.0.8)
# Requirement already satisfied: widgetsnbextension~=4.0.7 in /home/adam/.local/lib/python3.10/site-packages (from ipywidgets->jupyter==1.0.0->d2l) (4.0.8)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in /home/adam/.local/lib/python3.10/site-packages (from jupyter-console->jupyter==1.0.0->d2l) (3.0.39)
# Requirement already satisfied: pygments in /home/adam/.local/lib/python3.10/site-packages (from jupyter-console->jupyter==1.0.0->d2l) (2.16.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/adam/.local/lib/python3.10/site-packages (from nbconvert->jupyter==1.0.0->d2l) (1.5.0)
# Requirement already satisfied: defusedxml in /home/adam/.local/lib/python3.10/site-packages (from nbconvert->jupyter==1.0.0->d2l) (0.7.1)
# Requirement already satisfied: beautifulsoup4 in /home/adam/.local/lib/python3.10/site-packages (from nbconvert->jupyter==1.0.0->d2l) (4.12.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in /home/adam/.local/lib/python3.10/site-packages (from nbconvert->jupyter==1.0.0->d2l) (3.0.1)
# Requirement already satisfied: nbformat>=5.7 in /home/adam/.local/lib/python3.10/site-packages (from nbconvert->jupyter==1.0.0->d2l) (5.9.2)
# Requirement already satisfied: jupyterlab-pygments in /home/adam/.local/lib/python3.10/site-packages (from nbconvert->jupyter==1.0.0->d2l) (0.2.2)
# Requirement already satisfied: nbclient>=0.5.0 in /home/adam/.local/lib/python3.10/site-packages (from nbconvert->jupyter==1.0.0->d2l) (0.8.0)
# Requirement already satisfied: bleach!=5.0.0 in /home/adam/.local/lib/python3.10/site-packages (from nbconvert->jupyter==1.0.0->d2l) (6.0.0)
# Requirement already satisfied: tinycss2 in /home/adam/.local/lib/python3.10/site-packages (from nbconvert->jupyter==1.0.0->d2l) (1.2.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in /home/adam/.local/lib/python3.10/site-packages (from notebook->jupyter==1.0.0->d2l) (2.24.0)
# Requirement already satisfied: jupyterlab<5,>=4.0.2 in /home/adam/.local/lib/python3.10/site-packages (from notebook->jupyter==1.0.0->d2l) (4.0.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /home/adam/.local/lib/python3.10/site-packages (from notebook->jupyter==1.0.0->d2l) (2.7.3)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /home/adam/.local/lib/python3.10/site-packages (from notebook->jupyter==1.0.0->d2l) (0.2.3)
# Requirement already satisfied: ipython-genutils in /home/adam/.local/lib/python3.10/site-packages (from qtconsole->jupyter==1.0.0->d2l) (0.2.0)
# Requirement already satisfied: qtpy>=2.4.0 in /home/adam/.local/lib/python3.10/site-packages (from qtconsole->jupyter==1.0.0->d2l) (2.4.0)
# Requirement already satisfied: webencodings in /home/adam/.local/lib/python3.10/site-packages (from bleach!=5.0.0->nbconvert->jupyter==1.0.0->d2l) (0.5.1)
# Requirement already satisfied: decorator in /home/adam/.local/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/adam/.local/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (0.18.2)
# Requirement already satisfied: backcall in /home/adam/.local/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (0.2.0)
# Requirement already satisfied: pickleshare in /home/adam/.local/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (0.7.5)
# Requirement already satisfied: pexpect>4.3 in /home/adam/.local/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (4.8.0)
# Requirement already satisfied: platformdirs>=2.5 in /home/adam/.local/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter==1.0.0->d2l) (3.10.0)
# Requirement already satisfied: jupyter-server-terminals in /home/adam/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (0.4.4)
# Requirement already satisfied: websocket-client in /home/adam/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (1.6.2)
# Requirement already satisfied: anyio>=3.1.0 in /home/adam/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (4.0.0)
# Requirement already satisfied: jupyter-events>=0.6.0 in /home/adam/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (0.7.0)
# Requirement already satisfied: send2trash>=1.8.2 in /home/adam/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /home/adam/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (0.17.1)
# Requirement already satisfied: prometheus-client in /home/adam/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (0.17.1)
# Requirement already satisfied: argon2-cffi in /home/adam/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (23.1.0)
# Requirement already satisfied: overrides in /home/adam/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (7.4.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /home/adam/.local/lib/python3.10/site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter==1.0.0->d2l) (2.2.0)
# Requirement already satisfied: tomli in /home/adam/.local/lib/python3.10/site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter==1.0.0->d2l) (2.0.1)
# Requirement already satisfied: async-lru>=1.0.0 in /home/adam/.local/lib/python3.10/site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter==1.0.0->d2l) (2.0.4)
# Requirement already satisfied: babel>=2.10 in /home/adam/.local/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter==1.0.0->d2l) (2.12.1)
# Requirement already satisfied: json5>=0.9.0 in /home/adam/.local/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter==1.0.0->d2l) (0.9.14)
# Requirement already satisfied: jsonschema>=4.17.3 in /home/adam/.local/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter==1.0.0->d2l) (4.19.0)
# Requirement already satisfied: fastjsonschema in /home/adam/.local/lib/python3.10/site-packages (from nbformat>=5.7->nbconvert->jupyter==1.0.0->d2l) (2.18.0)
# Requirement already satisfied: wcwidth in /home/adam/.local/lib/python3.10/site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter==1.0.0->d2l) (0.2.6)
# Requirement already satisfied: soupsieve>1.2 in /home/adam/.local/lib/python3.10/site-packages (from beautifulsoup4->nbconvert->jupyter==1.0.0->d2l) (2.5)
# Requirement already satisfied: sniffio>=1.1 in /home/adam/.local/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/adam/.local/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (1.1.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/adam/.local/lib/python3.10/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (0.8.3)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/adam/.local/lib/python3.10/site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook->jupyter==1.0.0->d2l) (0.10.2)
# Requirement already satisfied: attrs>=22.2.0 in /home/adam/.local/lib/python3.10/site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook->jupyter==1.0.0->d2l) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/adam/.local/lib/python3.10/site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook->jupyter==1.0.0->d2l) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/adam/.local/lib/python3.10/site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook->jupyter==1.0.0->d2l) (0.30.2)
# Requirement already satisfied: rfc3339-validator in /home/adam/.local/lib/python3.10/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (0.1.4)
# Requirement already satisfied: pyyaml>=5.3 in /usr/lib/python3/dist-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (5.4.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/adam/.local/lib/python3.10/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (2.0.7)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/adam/.local/lib/python3.10/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (0.1.1)
# Requirement already satisfied: ptyprocess>=0.5 in /home/adam/.local/lib/python3.10/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /home/adam/.local/lib/python3.10/site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (21.2.0)
# Requirement already satisfied: fqdn in /home/adam/.local/lib/python3.10/site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook->jupyter==1.0.0->d2l) (1.5.1)
# Requirement already satisfied: isoduration in /home/adam/.local/lib/python3.10/site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook->jupyter==1.0.0->d2l) (20.11.0)
# Requirement already satisfied: uri-template in /home/adam/.local/lib/python3.10/site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook->jupyter==1.0.0->d2l) (1.3.0)
# Requirement already satisfied: jsonpointer>1.13 in /home/adam/.local/lib/python3.10/site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook->jupyter==1.0.0->d2l) (2.4)
# Requirement already satisfied: webcolors>=1.11 in /home/adam/.local/lib/python3.10/site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook->jupyter==1.0.0->d2l) (1.13)
# Requirement already satisfied: cffi>=1.0.1 in /home/adam/.local/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (1.15.1)
# Requirement already satisfied: pycparser in /home/adam/.local/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in /home/adam/.local/lib/python3.10/site-packages (from isoduration->jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook->jupyter==1.0.0->d2l) (1.2.3)
# Note: you may need to restart the kernel to use updated packages.
